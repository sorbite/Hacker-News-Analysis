# %% [markdown]
# # Post context processing

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# ## Pre-processing Data

# %%
# read in the row text
raw_data = open('HN_posts_year_to_Sep_26_2016.csv')

# %%
import pandas as pd
data = pd.read_csv('HN_posts_year_to_Sep_26_2016.csv', sep = ',')
data.head()
# Out:
#          id                                              title  \
# 0  12579008  You have two days to comment if you want stem ...
# 1  12579005                         SQLAR  the SQLite Archiver
# 2  12578997  What if we just printed a flatscreen televisio...
# 3  12578989                                  algorithmic music
# 4  12578979  How the Data Vault Enables the Next-Gen Data W...
#
#                                                  url  num_points  \
# 0  http://www.regulations.gov/document?D=FDA-2015...           1
# 1   https://www.sqlite.org/sqlar/doc/trunk/README.md           1
# 2  https://medium.com/vanmoof/our-secrets-out-f21...           1
# 3  http://cacm.acm.org/magazines/2011/7/109891-al...           1
# 4  https://www.talend.com/blog/2016/05/12/talend-...           1
#
#    num_comments        author      created_at
# 0             0       altstar  9/26/2016 3:26
# 1             0      blacksqr  9/26/2016 3:24
# 2             0  pavel_lishin  9/26/2016 3:19
# 3             0  poindontcare  9/26/2016 3:16
# 4             0   markgainor1  9/26/2016 3:14

# %% [markdown]
# ### Remove punctuation in the comments

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# Function to remove punctuations in the comments
def remove_punct(text):
    text_nonpunct = "".join([char for char in text if char not in string.punctuation])
    return text_nonpunct

data['title_clean'] = data['title'].apply(lambda x: remove_punct(x))

data.head()
# Out:
#          id                                              title  \
# 0  12579008  You have two days to comment if you want stem ...
# 1  12579005                         SQLAR  the SQLite Archiver
# 2  12578997  What if we just printed a flatscreen televisio...
# 3  12578989                                  algorithmic music
# 4  12578979  How the Data Vault Enables the Next-Gen Data W...
#
#                                                  url  num_points  \
# 0  http://www.regulations.gov/document?D=FDA-2015...           1
# 1   https://www.sqlite.org/sqlar/doc/trunk/README.md           1
# 2  https://medium.com/vanmoof/our-secrets-out-f21...           1
# 3  http://cacm.acm.org/magazines/2011/7/109891-al...           1
# 4  https://www.talend.com/blog/2016/05/12/talend-...           1
#
#    num_comments        author      created_at  \
# 0             0       altstar  9/26/2016 3:26
# 1             0      blacksqr  9/26/2016 3:24
# 2             0  pavel_lishin  9/26/2016 3:19
# 3             0  poindontcare  9/26/2016 3:16
# 4             0   markgainor1  9/26/2016 3:14
#
#                                          title_clean
# 0  You have two days to comment if you want stem ...
# 1                         SQLAR  the SQLite Archiver
# 2  What if we just printed a flatscreen televisio...
# 3                                  algorithmic music
# 4  How the Data Vault Enables the NextGen Data Wa...

# %% [markdown]
# ### Tokenization of users' comments

# %%
import re

# define the function to tokenize words

def tokenize(text):
    token = re.split('\W+',text)
    return token

data['body_text_tokenized'] = data['title_clean'].apply(lambda x: tokenize(x.lower()))
data.head()
# Out:
#          id                                              title  \
# 0  12579008  You have two days to comment if you want stem ...
# 1  12579005                         SQLAR  the SQLite Archiver
# 2  12578997  What if we just printed a flatscreen televisio...
# 3  12578989                                  algorithmic music
# 4  12578979  How the Data Vault Enables the Next-Gen Data W...
#
#                                                  url  num_points  \
# 0  http://www.regulations.gov/document?D=FDA-2015...           1
# 1   https://www.sqlite.org/sqlar/doc/trunk/README.md           1
# 2  https://medium.com/vanmoof/our-secrets-out-f21...           1
# 3  http://cacm.acm.org/magazines/2011/7/109891-al...           1
# 4  https://www.talend.com/blog/2016/05/12/talend-...           1
#
#    num_comments        author      created_at  \
# 0             0       altstar  9/26/2016 3:26
# 1             0      blacksqr  9/26/2016 3:24
# 2             0  pavel_lishin  9/26/2016 3:19
# 3             0  poindontcare  9/26/2016 3:16
# 4             0   markgainor1  9/26/2016 3:14
#
#                                          title_clean  \
# 0  You have two days to comment if you want stem ...
# 1                         SQLAR  the SQLite Archiver
# 2  What if we just printed a flatscreen televisio...
# 3                                  algorithmic music
# 4  How the Data Vault Enables the NextGen Data Wa...
#
#                                  body_text_tokenized
# 0  [you, have, two, days, to, comment, if, you, w...
# 1                     [sqlar, the, sqlite, archiver]
# 2  [what, if, we, just, printed, a, flatscreen, t...
# 3                               [algorithmic, music]
# 4  [how, the, data, vault, enables, the, nextgen,...

# %% [markdown]
# ### Remove stopwords

# %%
import nltk
stopword = nltk.corpus.stopwords.words('english')

# %%
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopword]
    return text

data['body_text_nonstop'] = data['body_text_tokenized'].apply(lambda x: remove_stopwords(x))
data.head()
# Out:
#          id                                              title  \
# 0  12579008  You have two days to comment if you want stem ...
# 1  12579005                         SQLAR  the SQLite Archiver
# 2  12578997  What if we just printed a flatscreen televisio...
# 3  12578989                                  algorithmic music
# 4  12578979  How the Data Vault Enables the Next-Gen Data W...
#
#                                                  url  num_points  \
# 0  http://www.regulations.gov/document?D=FDA-2015...           1
# 1   https://www.sqlite.org/sqlar/doc/trunk/README.md           1
# 2  https://medium.com/vanmoof/our-secrets-out-f21...           1
# 3  http://cacm.acm.org/magazines/2011/7/109891-al...           1
# 4  https://www.talend.com/blog/2016/05/12/talend-...           1
#
#    num_comments        author      created_at  \
# 0             0       altstar  9/26/2016 3:26
# 1             0      blacksqr  9/26/2016 3:24
# 2             0  pavel_lishin  9/26/2016 3:19
# 3             0  poindontcare  9/26/2016 3:16
# 4             0   markgainor1  9/26/2016 3:14
#
#                                          title_clean  \
# 0  You have two days to comment if you want stem ...
# 1                         SQLAR  the SQLite Archiver
# 2  What if we just printed a flatscreen televisio...
# 3                                  algorithmic music
# 4  How the Data Vault Enables the NextGen Data Wa...
#
#                                  body_text_tokenized  \
# 0  [you, have, two, days, to, comment, if, you, w...
# 1                     [sqlar, the, sqlite, archiver]
# 2  [what, if, we, just, printed, a, flatscreen, t...
# 3                               [algorithmic, music]
# 4  [how, the, data, vault, enables, the, nextgen,...
#
#                                    body_text_nonstop
# 0  [two, days, comment, want, stem, cells, classi...
# 1                          [sqlar, sqlite, archiver]
# 2     [printed, flatscreen, television, side, boxes]
# 3                               [algorithmic, music]
# 4  [data, vault, enables, nextgen, data, warehous...

# %% [markdown]
# ### Stemming

# %%
ps = nltk.PorterStemmer()

def stemming(tokenized_text):
    text = [ps.stem(word) for word in tokenized_text]
    return text

data['body_text_stemmed'] = data['body_text_nonstop'].apply(lambda x: stemming(x))
data.head()
# Out:
#          id                                              title  \
# 0  12579008  You have two days to comment if you want stem ...
# 1  12579005                         SQLAR  the SQLite Archiver
# 2  12578997  What if we just printed a flatscreen televisio...
# 3  12578989                                  algorithmic music
# 4  12578979  How the Data Vault Enables the Next-Gen Data W...
#
#                                                  url  num_points  \
# 0  http://www.regulations.gov/document?D=FDA-2015...           1
# 1   https://www.sqlite.org/sqlar/doc/trunk/README.md           1
# 2  https://medium.com/vanmoof/our-secrets-out-f21...           1
# 3  http://cacm.acm.org/magazines/2011/7/109891-al...           1
# 4  https://www.talend.com/blog/2016/05/12/talend-...           1
#
#    num_comments        author      created_at  \
# 0             0       altstar  9/26/2016 3:26
# 1             0      blacksqr  9/26/2016 3:24
# 2             0  pavel_lishin  9/26/2016 3:19
# 3             0  poindontcare  9/26/2016 3:16
# 4             0   markgainor1  9/26/2016 3:14
#
#                                          title_clean  \
# 0  You have two days to comment if you want stem ...
# 1                         SQLAR  the SQLite Archiver
# 2  What if we just printed a flatscreen televisio...
# 3                                  algorithmic music
# 4  How the Data Vault Enables the NextGen Data Wa...
#
#                                  body_text_tokenized  \
# 0  [you, have, two, days, to, comment, if, you, w...
# 1                     [sqlar, the, sqlite, archiver]
# 2  [what, if, we, just, printed, a, flatscreen, t...
# 3                               [algorithmic, music]
# 4  [how, the, data, vault, enables, the, nextgen,...
#
#                                    body_text_nonstop  \
# 0  [two, days, comment, want, stem, cells, classi...
# 1                          [sqlar, sqlite, archiver]
# 2     [printed, flatscreen, television, side, boxes]
# 3                               [algorithmic, music]
# 4  [data, vault, enables, nextgen, data, warehous...
#
#                                    body_text_stemmed
# 0    [two, day, comment, want, stem, cell, classifi]
# 1                            [sqlar, sqlite, archiv]
# 2            [print, flatscreen, televis, side, box]
# 3                                 [algorithm, music]
# 4  [data, vault, enabl, nextgen, data, warehous, ...

# %% [markdown]
# ### Lemmatizing

# %%
import nltk

wl = nltk.WordNetLemmatizer()

def lemmatizing(tokenized_text):
    text = [wl.lemmatize(word) for word in tokenized_text]
    return text

data['body_text_lemmatized'] = data['body_text_nonstop'].apply(lambda x: lemmatizing(x))
data.head()
# Out:
#          id                                              title  \
# 0  12579008  You have two days to comment if you want stem ...
# 1  12579005                         SQLAR  the SQLite Archiver
# 2  12578997  What if we just printed a flatscreen televisio...
# 3  12578989                                  algorithmic music
# 4  12578979  How the Data Vault Enables the Next-Gen Data W...
#
#                                                  url  num_points  \
# 0  http://www.regulations.gov/document?D=FDA-2015...           1
# 1   https://www.sqlite.org/sqlar/doc/trunk/README.md           1
# 2  https://medium.com/vanmoof/our-secrets-out-f21...           1
# 3  http://cacm.acm.org/magazines/2011/7/109891-al...           1
# 4  https://www.talend.com/blog/2016/05/12/talend-...           1
#
#    num_comments        author      created_at  \
# 0             0       altstar  9/26/2016 3:26
# 1             0      blacksqr  9/26/2016 3:24
# 2             0  pavel_lishin  9/26/2016 3:19
# 3             0  poindontcare  9/26/2016 3:16
# 4             0   markgainor1  9/26/2016 3:14
#
#                                          title_clean  \
# 0  You have two days to comment if you want stem ...
# 1                         SQLAR  the SQLite Archiver
# 2  What if we just printed a flatscreen televisio...
# 3                                  algorithmic music
# 4  How the Data Vault Enables the NextGen Data Wa...
#
#                                  body_text_tokenized  \
# 0  [you, have, two, days, to, comment, if, you, w...
# 1                     [sqlar, the, sqlite, archiver]
# 2  [what, if, we, just, printed, a, flatscreen, t...
# 3                               [algorithmic, music]
# 4  [how, the, data, vault, enables, the, nextgen,...
#
#                                    body_text_nonstop  \
# 0  [two, days, comment, want, stem, cells, classi...
# 1                          [sqlar, sqlite, archiver]
# 2     [printed, flatscreen, television, side, boxes]
# 3                               [algorithmic, music]
# 4  [data, vault, enables, nextgen, data, warehous...
#
#                                    body_text_stemmed  \
# 0    [two, day, comment, want, stem, cell, classifi]
# 1                            [sqlar, sqlite, archiv]
# 2            [print, flatscreen, televis, side, box]
# 3                                 [algorithm, music]
# 4  [data, vault, enabl, nextgen, data, warehous, ...
#
#                                 body_text_lemmatized
# 0  [two, day, comment, want, stem, cell, classified]
# 1                          [sqlar, sqlite, archiver]
# 2       [printed, flatscreen, television, side, box]
# 3                               [algorithmic, music]
# 4  [data, vault, enables, nextgen, data, warehous...

# %% [markdown]
# ### Apply the CountVectorizer (Bag-Of-Words)

# %%
def clean_text(text):
    text = "".join([word.lower() for word in text if word not in string.punctuation])
    tokens = re.split('\W+', text)
    text = [ps.stem(word) for word in tokens if word not in stopwords]
    return text

from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer(analyzer = clean_text)
x_counts = count_vect.fit_transform(data['title'])
print(x_counts.shape)
print(count_vect.get_feature_names())
# Out:
# (293119, 78620)
# ['', '0', '00', '000', '0000', '000000', '00001', '0002gbmonth', '0005gb', '000webhost', '000webhostcom', '001', '0017', '001liter', '001pper', '002', '003', '003version', '005', '0052', '006', '007', '008', '00ec454pop', '00ffff', '01', '010', '0100', '010000', '01000mph', '01001', '0100kph', '0100m', '0101', '01010', '01013', '01050', '010b5', '010releas', '010x', '011', '0110', '01100101', '0112', '012', '0120', '012016', '0125', '013', '0130', '014', '0140', '0141', '0144', '0147', '015', '0150', '0151', '0152', '0154', '016', '0160', '01650013', '017', '0170', '0175', '0180', '0183', '019', '0191', '01x', '02', '020', '0200', '02016', '020incub', '021', '0210', '022', '0223', '022316', '023', '024', '025', '026', '027', '0270', '028', '029', '03', '030', '0300', '031', '034', '035', '036', '0370', '038', '04', '040', '04042016', '04072016', '040beta', '040incub', '041', '0416', '042', '04201', '04305', '0444', '046', '049', '0492', '0498', '05', '050', '0502', '0505', '0506', '05082016', '051', '0515', '052', '0526', '054', '0549', '055', '057', '059', '05x', '06', '060', '0600', '061', '0610', '0612', '062', '0636', '06385', '066', '067', '068', '069', '06k', '07', '070', '071', '075', '0778', '08', '080', '0800', '080alpha', '080rc3', '081', '08134', '0814', '0815', '0816', '081623', '0817', '0818', '082', '0820', '082015', '083', '0830', '084', '087', '088', '08gp46180kr', '08mm', '08x', '09', '090', '0900', '0901', '0909', '091', '0914', '09140', '092014', '0931', '093b', '094', '095', '095rc2', '096', '099', '0993', '099399', '0ad', '0auth', '0bsd', '0day', '0e329232ea6d0d73', '0fc', '0feetaway', '0for3', '0hassl', '0index', '0k', '0n', '0patch', '0s', '0toillumo', '0wnz0red', '0x07', '0x09', '0x10', '0x100th', '0x10c', '0x11thi', '0x4015', '0x4c454554', '0x57', '0x59', '0x5c', '0x5d', '0x90', '0xaxlinuxinsid', '0xb01dfacedebac1', '0xdbe', '0xdeadbeef', '0â', '1', '10', '100', '1000', '10000', '100000', '1000000', '10000000', '1000000000000000000', '1000000th', '100000km', '100000plu', '100000th', '10000ayear', '10000charact', '10000ft', '10000hour', '10000kw', '10000line', '10000mo', '10000x', '10000yearold', '1000btc', '1000c', '1000employe', '1000fold', '1000horsepow', '1000hp', '1000km', '1000kv', '1000mile', '1000month', '1000mph', '1000node', '1000pflop', '1000processor', '1000w', '1000word', '1000x', '1000year', '1000yearold', '1001', '100100', '100101', '1001tweet', '1002', '100200', '1003', '10080', '100b', '100beta1', '100bn', '100day', '100daysofreactj', '100euro', '100foot', '100ft', '100g', '100gb', '100gbmonth', '100gbp', '100gig', '100hat', '100hour', '100incubatingm3', '100k', '100kilomet', '100km', '100kmayb', '100kmh', '100kmonth', '100kw', '100kwh', '100kyear', '100kâ', '100m', '100m1', '100m90m', '100mb', '100mbp', '100meter', '100meuro', '100mhz', '100mm', '100mn', '100mp', '100mph', '100msp', '100percent', '100person', '100rc1', '100t', '100tb', '100th', '100x', '100year', '100yearold', '100yo', '100yr', '101', '1010', '101000', '10105', '1011', '10111', '10112', '10113', '101130am', '10114', '10115', '1012', '1013', '1015', '101519114004', '1015229', '1015am', '1016', '101815', '1019', '101free', '101gb', '101hero', '101m', '101our', '101r', '101st', '101u', '102', '1020pm', '1020tb', '1020x', '1024', '10240', '1024bit', '1024d', '1024x512', '1025', '1027', '10292015', '102b', '102f', '102h', '102i', '102m', '102yearold', '103', '1030', '103000', '1031', '103210', '10328x7760', '10345', '1035', '1036m', '1037', '103m', '103rc1', '103rc2', '103releas', '104', '1040', '104k', '104yearold', '105', '105b', '105c', '105hour', '105m', '105page', '106', '1060', '106000', '1061', '106108', '10659', '1068100', '106b', '106k', '106m', '107', '1070', '1075m', '1077', '107m', '107mph', '107x', '108', '1080', '1080m', '1080p', '1085ghz', '108b', '108m', '108slide', '108x', '109', '1092', '1095', '1099', '109m', '10abarrel', '10am', '10aud', '10b', '10bar', '10beta', '10beta2', '10bit', '10bn', '10byr', '10c ...

# %% [markdown]
# ### Apply the CountVectorizer (N-Grams)

# %%
ngram_vect = CountVectorizer(ngram_range = (2,2), analyzer = clean_text)
x_counts = ngram_vect.fit_transform(data['title'])
print(x_counts.shape)
print(count_vect.get_feature_names())
# Out:
# (293119, 78620)
# ['', '0', '00', '000', '0000', '000000', '00001', '0002gbmonth', '0005gb', '000webhost', '000webhostcom', '001', '0017', '001liter', '001pper', '002', '003', '003version', '005', '0052', '006', '007', '008', '00ec454pop', '00ffff', '01', '010', '0100', '010000', '01000mph', '01001', '0100kph', '0100m', '0101', '01010', '01013', '01050', '010b5', '010releas', '010x', '011', '0110', '01100101', '0112', '012', '0120', '012016', '0125', '013', '0130', '014', '0140', '0141', '0144', '0147', '015', '0150', '0151', '0152', '0154', '016', '0160', '01650013', '017', '0170', '0175', '0180', '0183', '019', '0191', '01x', '02', '020', '0200', '02016', '020incub', '021', '0210', '022', '0223', '022316', '023', '024', '025', '026', '027', '0270', '028', '029', '03', '030', '0300', '031', '034', '035', '036', '0370', '038', '04', '040', '04042016', '04072016', '040beta', '040incub', '041', '0416', '042', '04201', '04305', '0444', '046', '049', '0492', '0498', '05', '050', '0502', '0505', '0506', '05082016', '051', '0515', '052', '0526', '054', '0549', '055', '057', '059', '05x', '06', '060', '0600', '061', '0610', '0612', '062', '0636', '06385', '066', '067', '068', '069', '06k', '07', '070', '071', '075', '0778', '08', '080', '0800', '080alpha', '080rc3', '081', '08134', '0814', '0815', '0816', '081623', '0817', '0818', '082', '0820', '082015', '083', '0830', '084', '087', '088', '08gp46180kr', '08mm', '08x', '09', '090', '0900', '0901', '0909', '091', '0914', '09140', '092014', '0931', '093b', '094', '095', '095rc2', '096', '099', '0993', '099399', '0ad', '0auth', '0bsd', '0day', '0e329232ea6d0d73', '0fc', '0feetaway', '0for3', '0hassl', '0index', '0k', '0n', '0patch', '0s', '0toillumo', '0wnz0red', '0x07', '0x09', '0x10', '0x100th', '0x10c', '0x11thi', '0x4015', '0x4c454554', '0x57', '0x59', '0x5c', '0x5d', '0x90', '0xaxlinuxinsid', '0xb01dfacedebac1', '0xdbe', '0xdeadbeef', '0â', '1', '10', '100', '1000', '10000', '100000', '1000000', '10000000', '1000000000000000000', '1000000th', '100000km', '100000plu', '100000th', '10000ayear', '10000charact', '10000ft', '10000hour', '10000kw', '10000line', '10000mo', '10000x', '10000yearold', '1000btc', '1000c', '1000employe', '1000fold', '1000horsepow', '1000hp', '1000km', '1000kv', '1000mile', '1000month', '1000mph', '1000node', '1000pflop', '1000processor', '1000w', '1000word', '1000x', '1000year', '1000yearold', '1001', '100100', '100101', '1001tweet', '1002', '100200', '1003', '10080', '100b', '100beta1', '100bn', '100day', '100daysofreactj', '100euro', '100foot', '100ft', '100g', '100gb', '100gbmonth', '100gbp', '100gig', '100hat', '100hour', '100incubatingm3', '100k', '100kilomet', '100km', '100kmayb', '100kmh', '100kmonth', '100kw', '100kwh', '100kyear', '100kâ', '100m', '100m1', '100m90m', '100mb', '100mbp', '100meter', '100meuro', '100mhz', '100mm', '100mn', '100mp', '100mph', '100msp', '100percent', '100person', '100rc1', '100t', '100tb', '100th', '100x', '100year', '100yearold', '100yo', '100yr', '101', '1010', '101000', '10105', '1011', '10111', '10112', '10113', '101130am', '10114', '10115', '1012', '1013', '1015', '101519114004', '1015229', '1015am', '1016', '101815', '1019', '101free', '101gb', '101hero', '101m', '101our', '101r', '101st', '101u', '102', '1020pm', '1020tb', '1020x', '1024', '10240', '1024bit', '1024d', '1024x512', '1025', '1027', '10292015', '102b', '102f', '102h', '102i', '102m', '102yearold', '103', '1030', '103000', '1031', '103210', '10328x7760', '10345', '1035', '1036m', '1037', '103m', '103rc1', '103rc2', '103releas', '104', '1040', '104k', '104yearold', '105', '105b', '105c', '105hour', '105m', '105page', '106', '1060', '106000', '1061', '106108', '10659', '1068100', '106b', '106k', '106m', '107', '1070', '1075m', '1077', '107m', '107mph', '107x', '108', '1080', '1080m', '1080p', '1085ghz', '108b', '108m', '108slide', '108x', '109', '1092', '1095', '1099', '109m', '10abarrel', '10am', '10aud', '10b', '10bar', '10beta', '10beta2', '10bit', '10bn', '10byr', '10c ...

# %% [markdown]
# ### Apply TfidVectorizer

# %%
from sklearn.feature_extraction.text import TfidVectorizer

tfidf_vect = TfidVectorizer(analyzer = clean_text)
x_tfidf = tfidf_vect.fit_transform(data['title'])
print(x_counts.shape)
print(count_vect.get_feature_names())

# %% [markdown]
# ### ML Classifiers

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
rf = RandomForestClassifier()
param = {'n_estimators': [10, 150, 300],
        'max_depth': [30, 60, 90, None]}

gs = GridSearchCV(rf, param, cv=5, n_jobs=-1)
gs_fit = gs.fit(X_count_feat, data['title'])
pd.DataFrame(gs_fit.cv_results_).sort_values('mean_test_score', ascending=False).head()
